# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Normalize pixel values
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Convert labels to one-hot encoding
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)
# Flatten the input data
x_train = x_train.reshape((-1, 784))
x_test = x_test.reshape((-1, 784))
model = keras.Sequential([
 layers.Dense(256, activation="relu", input_shape=(784,)),
 layers.Dense(128, activation="relu"),
 layers.Dense(10, activation="softmax")
])
# Define the optimizers to compare
sgd_optimizer = keras.optimizers.SGD(learning_rate=0.01)
rmsprop_optimizer = keras.optimizers.RMSprop(learning_rate=0.001)
adam_optimizer = keras.optimizers.Adam(learning_rate=0.001)
# Compile the model with each optimizer and train it
model.compile(optimizer=sgd_optimizer, loss="categorical_crossentropy", metrics=["accuracy"])
history_sgd = model.fit(x_train, y_train, epochs=10, batch_size=128, validation_split=0.2)
model.compile(optimizer=rmsprop_optimizer, loss="categorical_crossentropy", metrics=["accuracy"])
history_rmsprop = model.fit(x_train, y_train, epochs=10, batch_size=128, validation_split=0.2)
model.compile(optimizer=adam_optimizer, loss="categorical_crossentropy", metrics=["accuracy"])
history_adam = model.fit(x_train, y_train, epochs=10, batch_size=128, validation_split=0.2)
# Evaluate the model with each optimizer on the test set
test_loss_sgd, test_acc_sgd = model.evaluate(x_test, y_test)
test_loss_rmsprop, test_acc_rmsprop = model.evaluate(x_test, y_test)
test_loss_adam, test_acc_adam = model.evaluate(x_test, y_test)
print("SGD test accuracy:", test_acc_sgd)
print("RMSprop test accuracy:", test_acc_rmsprop)
print("Adam test accuracy:", test_acc_adam)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# Epoch 1/10
# 375/375 [==============================] - 8s 20ms/step - loss: 1.1187 - accuracy: 0.6632 - val_loss: 0.7517 - val_accuracy: 0.7452
# Epoch 2/10
# 375/375 [==============================] - 3s 7ms/step - loss: 0.6746 - accuracy: 0.7820 - val_loss: 0.6140 - val_accuracy: 0.7962
# Epoch 3/10
# 375/375 [==============================] - 3s 9ms/step - loss: 0.5843 - accuracy: 0.8084 - val_loss: 0.5538 - val_accuracy: 0.8148
# Epoch 4/10
# 375/375 [==============================] - 2s 6ms/step - loss: 0.5375 - accuracy: 0.8204 - val_loss: 0.5243 - val_accuracy: 0.8250
# Epoch 5/10
# 375/375 [==============================] - 2s 6ms/step - loss: 0.5067 - accuracy: 0.8286 - val_loss: 0.4999 - val_accuracy: 0.8274
# Epoch 6/10
# 375/375 [==============================] - 2s 6ms/step - loss: 0.4868 - accuracy: 0.8330 - val_loss: 0.4797 - val_accuracy: 0.8328
# Epoch 7/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.4700 - accuracy: 0.8388 - val_loss: 0.4770 - val_accuracy: 0.8328
# Epoch 8/10
# 375/375 [==============================] - 2s 6ms/step - loss: 0.4583 - accuracy: 0.8435 - val_loss: 0.4665 - val_accuracy: 0.8381
# Epoch 9/10
# 375/375 [==============================] - 3s 7ms/step - loss: 0.4471 - accuracy: 0.8456 - val_loss: 0.4515 - val_accuracy: 0.8428
# Epoch 10/10
# 375/375 [==============================] - 2s 6ms/step - loss: 0.4377 - accuracy: 0.8486 - val_loss: 0.4430 - val_accuracy: 0.8457
# Epoch 1/10
# 375/375 [==============================] - 3s 7ms/step - loss: 0.5266 - accuracy: 0.8176 - val_loss: 0.5262 - val_accuracy: 0.8033
# Epoch 2/10
# 375/375 [==============================] - 2s 7ms/step - loss: 0.3908 - accuracy: 0.8570 - val_loss: 0.3787 - val_accuracy: 0.8621
# Epoch 3/10
# 375/375 [==============================] - 4s 11ms/step - loss: 0.3455 - accuracy: 0.8735 - val_loss: 0.3824 - val_accuracy: 0.8587
# Epoch 4/10
# 375/375 [==============================] - 2s 6ms/step - loss: 0.3200 - accuracy: 0.8810 - val_loss: 0.3557 - val_accuracy: 0.8693
# Epoch 5/10
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2971 - accuracy: 0.8894 - val_loss: 0.3547 - val_accuracy: 0.8719
# Epoch 6/10
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2807 - accuracy: 0.8946 - val_loss: 0.3688 - val_accuracy: 0.8710
# Epoch 7/10
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2695 - accuracy: 0.8982 - val_loss: 0.3312 - val_accuracy: 0.8852
# Epoch 8/10
# 375/375 [==============================] - 3s 9ms/step - loss: 0.2562 - accuracy: 0.9034 - val_loss: 0.3737 - val_accuracy: 0.8759
# Epoch 9/10
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2456 - accuracy: 0.9079 - val_loss: 0.3280 - val_accuracy: 0.8844
# Epoch 10/10
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2337 - accuracy: 0.9129 - val_loss: 0.3491 - val_accuracy: 0.8804
# Epoch 1/10
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2237 - accuracy: 0.9158 - val_loss: 0.3280 - val_accuracy: 0.8917
# Epoch 2/10
# 375/375 [==============================] - 3s 9ms/step - loss: 0.2070 - accuracy: 0.9216 - val_loss: 0.3200 - val_accuracy: 0.8915
# Epoch 3/10
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1999 - accuracy: 0.9240 - val_loss: 0.3360 - val_accuracy: 0.8907
# Epoch 4/10
# 375/375 [==============================] - 2s 7ms/step - loss: 0.1913 - accuracy: 0.9274 - val_loss: 0.3194 - val_accuracy: 0.8928
# Epoch 5/10
# 375/375 [==============================] - 2s 7ms/step - loss: 0.1835 - accuracy: 0.9314 - val_loss: 0.3281 - val_accuracy: 0.8928
# Epoch 6/10
# 375/375 [==============================] - 2s 7ms/step - loss: 0.1780 - accuracy: 0.9319 - val_loss: 0.3422 - val_accuracy: 0.8875
# Epoch 7/10
# 375/375 [==============================] - 3s 9ms/step - loss: 0.1695 - accuracy: 0.9348 - val_loss: 0.3366 - val_accuracy: 0.8933
# Epoch 8/10
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1631 - accuracy: 0.9373 - val_loss: 0.3494 - val_accuracy: 0.8907
# Epoch 9/10
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1565 - accuracy: 0.9399 - val_loss: 0.3369 - val_accuracy: 0.8962
# Epoch 10/10
# 375/375 [==============================] - 2s 7ms/step - loss: 0.1552 - accuracy: 0.9408 - val_loss: 0.3420 - val_accuracy: 0.8989
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3662 - accuracy: 0.8910
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3662 - accuracy: 0.8910
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3662 - accuracy: 0.8910
# SGD test accuracy: 0.890999972820282
# RMSprop test accuracy: 0.890999972820282
# Adam test accuracy: 0.890999972820282
